# %% [markdown]
# -----
# # Kmean iris

# %%
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from kmeans import KMeans

# %%
iris = load_iris()
X_iris = iris.data
y_true = iris.target
scaler = StandardScaler()
X_iris = scaler.fit_transform(X_iris)

# %%
kmeans = KMeans(n_clusters=3)
labels = kmeans.fit_predict(X_iris)
silhouette_avg = silhouette_score(X_iris, labels)
print(f'Silhouette Score: {silhouette_avg:.2f}')
# Out:
# Silhouette Score: 0.46

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_iris)

# Create a figure with 1 row and 2 columns for the subplots
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

# Plot KMeans clustering results
for i in range(3):
    ax[0].scatter(X_pca[labels == i, 0], X_pca[labels == i, 1], label=f'Cluster {i}')
ax[0].set_xlabel('PCA Component 1')
ax[0].set_ylabel('PCA Component 2')
ax[0].set_title('KMeans Clustering of Iris Data')
ax[0].legend()

# Plot true labels
for i in range(3):
    ax[1].scatter(X_pca[y_true == i, 0], X_pca[y_true == i, 1], label=iris.target_names[i])
ax[1].set_xlabel('PCA Component 1')
ax[1].set_ylabel('PCA Component 2')
ax[1].set_title('True Labels of Iris Data')
ax[1].legend()

plt.show()

# %% [markdown]
# -----
# # FCM iris

# %%
from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from fcmeans import FCM

# %%
iris = load_iris()
X_iris = iris.data
y_true = iris.target
scaler = StandardScaler()
X_iris = scaler.fit_transform(X_iris)

# %%
# Apply FCM clustering
fcm = FCM(n_clusters=3)
fcm.fit(X_iris)
labels = fcm.predict(X_iris)
soft_labels = fcm.soft_predict(X_iris)
fcm_silhouette_avg = silhouette_score(X_iris, labels)
print(f'FCM Silhouette Score: {fcm_silhouette_avg:.2f}')
print("soft_labels:", soft_labels)
# Out:
# FCM Silhouette Score: 0.46
# soft_labels: [[9.91567563e-01 3.13530826e-03 5.29712882e-03]
#  [8.28961728e-01 5.18328691e-02 1.19205403e-01]
#  [9.29389530e-01 2.33115589e-02 4.72989109e-02]
#  [8.69534387e-01 4.12897394e-02 8.91758737e-02]
#  [9.73938863e-01 1.00118780e-02 1.60492586e-02]
#  [8.18796307e-01 7.92045781e-02 1.01999115e-01]
#  [9.59290720e-01 1.43676293e-02 2.63416506e-02]
#  [9.98273402e-01 6.12343073e-04 1.11425542e-03]
#  [7.40320042e-01 7.90958565e-02 1.80584101e-01]
#  [8.91217320e-01 3.44322452e-02 7.43504344e-02]
#  [9.08654795e-01 3.72759133e-02 5.40692912e-02]
#  [9.86305805e-01 4.82366769e-03 8.87052755e-03]
#  [8.29943290e-01 5.24622207e-02 1.17594489e-01]
#  [7.90005085e-01 6.78733909e-02 1.42121525e-01]
#  [7.44794515e-01 1.16733224e-01 1.38472261e-01]
#  [6.33255249e-01 1.79924628e-01 1.86820123e-01]
#  [8.27963792e-01 7.49764212e-02 9.70597870e-02]
#  [9.91721635e-01 3.07044871e-03 5.20791657e-03]
#  [8.05497609e-01 8.46240692e-02 1.09878322e-01]
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_iris)

# Create a figure with 1 row and 2 columns for the subplots
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

# Plot FCM clustering results
for i in range(4):
    ax[0].scatter(X_pca[labels == i, 0], X_pca[labels == i, 1], label=f'Cluster {i}')
ax[0].set_xlabel('PCA Component 1')
ax[0].set_ylabel('PCA Component 2')
ax[0].set_title('FCM Clustering of Iris Data')
ax[0].legend()

# Plot true labels
for i in range(3):
    ax[1].scatter(X_pca[y_true == i, 0], X_pca[y_true == i, 1], label=iris.target_names[i])
ax[1].set_xlabel('PCA Component 1')
ax[1].set_ylabel('PCA Component 2')
ax[1].set_title('True Labels of Iris Data')
ax[1].legend()

plt.show()

# %% [markdown]
# -----
# # Kmeans MNIST

# %%
from sklearn.datasets import fetch_openml
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from kmeans import KMeans
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# Load MNIST dataset
mnist = fetch_openml('mnist_784', version=1)
X_mnist = mnist.data
y_true = mnist.target.astype(int)  # Convert target to integers

# Standardize the data
scaler = StandardScaler()
X_mnist = scaler.fit_transform(X_mnist)

# Apply KMeans clustering
kmeans = KMeans(n_clusters=10)
labels = kmeans.fit_predict(X_mnist)
silhouette_avg = silhouette_score(X_mnist, labels)
print(f'Silhouette Score: {silhouette_avg:.2f}')

# t-SNE 
pca = PCA(n_components=2) 
X_pca = pca.fit_transform(X_mnist)

# Create a figure with 1 row and 2 columns for the subplots
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

# Plot KMeans clustering results
for i in range(10):
    ax[0].scatter(X_pca[labels == i, 0], X_pca[labels == i, 1], label=f'Cluster {i}')
ax[0].set_xlabel('PCA Component 1')
ax[0].set_ylabel('PCA Component 2')
ax[0].set_title('KMeans Clustering of MNIST Data')
ax[0].legend()

# Plot true labels
for i in range(10):
    ax[1].scatter(X_pca[y_true == i, 0], X_pca[y_true == i, 1], label=f'Digit {i}')
ax[1].set_xlabel('PCA Component 1')
ax[1].set_ylabel('PCA Component 2')
ax[1].set_title('True Labels of MNIST Data')
ax[1].legend()

plt.show()
# Out:
# Silhouette Score: 0.01

# %% [markdown]
# -----
# # FCM MNIST

# %%
from sklearn.datasets import fetch_openml
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from fcmeans import FCM

mnist = fetch_openml('mnist_784')
X_mnist = mnist.data
y_true = mnist.target
scaler = StandardScaler()
X_mnist = scaler.fit_transform(X_mnist)

# Apply FCM clustering
fcm = FCM(n_clusters=10)  # MNIST has 10 classes
fcm.fit(X_mnist)
labels = fcm.predict(X_mnist)
fcm_silhouette_avg = silhouette_score(X_mnist, labels)
print(f'FCM Silhouette Score: {fcm_silhouette_avg:.2f}')

import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# PCA
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_mnist)

# Create a figure with 1 row and 2 columns for the subplots
fig, ax = plt.subplots(1, 2, figsize=(20, 7))

# Plot FCM clustering results
for i in range(10):
    ax[0].scatter(X_pca[labels == i, 0], X_pca[labels == i, 1], label=f'Cluster {i}')
ax[0].set_xlabel('PCA Component 1')
ax[0].set_ylabel('PCA Component 2')
ax[0].set_title('FCM Clustering of MNIST Data')
ax[0].legend()

# Plot true labels
for i in range(10):
    ax[1].scatter(X_pca[y_true == i, 0], X_pca[y_true == i, 1], label=f'Digit {i}')
ax[1].set_xlabel('PCA Component 1')
ax[1].set_ylabel('PCA Component 2')
ax[1].set_title('True Labels of MNIST Data')
ax[1].legend()

plt.show()
# Out:
# FCM Silhouette Score: -0.03

# %%
from Library.UtilsTools.DataGenerater import get_linear_data

# %%
X,y = get_linear_data(size=(1000,4))
X.shape, y.shape
# Out:
# ((1000, 4), (1000, 1))

# %%
from Library.Algorithms import LinearRegression
import numpy as np

# %%
linear_regression = LinearRegression(inn=4, out=1)
linear_regression.Structure[1].RElevel=0

# %%
loss = linear_regression.train(X,y,Lr=0.00007,epoch=1000)
loss
# Out:
# 0.0025874398853789407

# %%
y_pred = linear_regression.evaluate(X)

# %%
from Library.UtilsTools.DataShower import show_2Dline
show_2Dline(False,y,y_pred)
